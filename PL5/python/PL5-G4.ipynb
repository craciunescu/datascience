# %% [markdown]
# # PL5-G4

# %% [markdown]
# The aim of this notebook is to document correctly the way of detecting outliers inside the Challenge Network datased.
#
# In order to do that, the first step consist on readind properly the data.

# %%
# Load needed packages
import pandas as pd

# Read CSV File, here we obtain a dataframe
df= pd.read_csv("SmallNetworkData.csv")
df
# Out:
#        1    0.000000   "Cisco_cd:c4:87"            PVST+           STP  \
# 0      2     2.004101    Cisco_cd:c4:87            PVST+           STP
# 1      3  1594.520130    Cisco_cd:c4:82            PVST+           STP
# 2      4  1594.592844    Cisco_cd:c4:86            PVST+           STP
# 3      5  1595.029504    Cisco_cd:c4:81            PVST+           STP
# 4      6  1595.366222    Cisco_cd:c4:85            PVST+           STP
# 5      7  1596.524573    Cisco_cd:c4:82            PVST+           STP
# 6      8  1596.596865    Cisco_cd:c4:86            PVST+           STP
# 7      9  1597.033340    Cisco_cd:c4:81            PVST+           STP
# 8     10  1597.370288    Cisco_cd:c4:85            PVST+           STP
# 9     11  1598.528551    Cisco_cd:c4:82            PVST+           STP
# 10    12  1598.600867    Cisco_cd:c4:86            PVST+           STP
# 11    13  1599.037134    Cisco_cd:c4:81            PVST+           STP
# ...

# %% [markdown]
# https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba
